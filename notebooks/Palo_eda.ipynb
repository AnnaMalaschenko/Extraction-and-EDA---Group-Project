# %% [markdown]
# After completing data_ingestion.py, each team member will conduct their own EDA. Every team member should create a file called [name]_eda.ipynb in the notebooks "folder" and explore the data using univariate and bivariate techniques. By completing separate EDAs,  we're able to split the workload of analyzing the dataset and come to independent conclusions which we can then share with the team.
#
# For example:
# notebooks/farukh_eda.ipynb
# notebooks/mickal_eda.ipynb
